# %% [markdown]
# #### Import libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import geopandas as gpd

# %%
# Ruta a tu archivo GeoJSON
ruta_geojson = "south-america.geojson"

# Abre el archivo GeoJSON con GeoPandas
gdf = gpd.read_file(ruta_geojson)

# Ahora 'gdf' es un GeoDataFrame que contiene tus datos GeoJSON
# Puedes imprimir las primeras filas para verificar
gdf.head()
# Out:
#    scalerank       featurecla  labelrank sovereignt sov_a3  adm0_dif  level  \
# 0          1  Admin-0 country          3    Bolivia    BOL         0      2
# 1          1  Admin-0 country          2     Brazil    BRA         0      2
# 2          1  Admin-0 country          2  Argentina    ARG         0      2
# 3          1  Admin-0 country          2      Chile    CHL         0      2
# 4          1  Admin-0 country          2   Colombia    COL         0      2
#
#                 type      admin adm0_a3  ...  region_un      subregion  \
# 0  Sovereign country    Bolivia     BOL  ...   Americas  South America
# 1  Sovereign country     Brazil     BRA  ...   Americas  South America
# 2  Sovereign country  Argentina     ARG  ...   Americas  South America
# 3  Sovereign country      Chile     CHL  ...   Americas  South America
# 4  Sovereign country   Colombia     COL  ...   Americas  South America
#
#                    region_wb  name_len long_len abbrev_len  tiny homepart  \
# ...

# %%
gdf
# Out:
#     scalerank       featurecla  labelrank      sovereignt sov_a3  adm0_dif  \
# 0           1  Admin-0 country          3         Bolivia    BOL         0
# 1           1  Admin-0 country          2          Brazil    BRA         0
# 2           1  Admin-0 country          2       Argentina    ARG         0
# 3           1  Admin-0 country          2           Chile    CHL         0
# 4           1  Admin-0 country          2        Colombia    COL         0
# 5           1  Admin-0 country          4          Guyana    GUY         0
# 6           1  Admin-0 country          3         Ecuador    ECU         0
# 7           1  Admin-0 country          2            Peru    PER         0
# 8           1  Admin-0 country          5  United Kingdom    GB1         1
# 9           1  Admin-0 country          4        Paraguay    PRY         0
# 10          1  Admin-0 country          4        Suriname    SUR         0
# ...

# %%
gdf[gdf["sov_a3"]=="BRA"]
# Out:
#    scalerank       featurecla  labelrank sovereignt sov_a3  adm0_dif  level  \
# 1          1  Admin-0 country          2     Brazil    BRA         0      2
#
#                 type   admin adm0_a3  ...  region_un      subregion  \
# 1  Sovereign country  Brazil     BRA  ...   Americas  South America
#
#                    region_wb  name_len long_len abbrev_len  tiny homepart  \
# 1  Latin America & Caribbean         6        6          6   -99        1
#
#       filename                                           geometry
# 1  BRA.geojson  POLYGON ((-57.62513 -30.2163, -56.2909 -28.852...
#
# [1 rows x 65 columns]

# %%
gdf[gdf["sov_a3"]=="ARG"]
# Out:
#    scalerank       featurecla  labelrank sovereignt sov_a3  adm0_dif  level  \
# 2          1  Admin-0 country          2  Argentina    ARG         0      2
#
#                 type      admin adm0_a3  ...  region_un      subregion  \
# 2  Sovereign country  Argentina     ARG  ...   Americas  South America
#
#                    region_wb  name_len long_len abbrev_len  tiny homepart  \
# 2  Latin America & Caribbean         9        9          4   -99        1
#
#       filename                                           geometry
# 2  ARG.geojson  MULTIPOLYGON (((-65.5 -55.2, -66.45 -55.25, -6...
#
# [1 rows x 65 columns]

# %%
gdf[gdf["sov_a3"]=="BOL"]
# Out:
#    scalerank       featurecla  labelrank sovereignt sov_a3  adm0_dif  level  \
# 0          1  Admin-0 country          3    Bolivia    BOL         0      2
#
#                 type    admin adm0_a3  ...  region_un      subregion  \
# 0  Sovereign country  Bolivia     BOL  ...   Americas  South America
#
#                    region_wb  name_len long_len abbrev_len  tiny homepart  \
# 0  Latin America & Caribbean         7        7          7   -99        1
#
#       filename                                           geometry
# 0  BOL.geojson  POLYGON ((-62.84647 -22.03498, -63.98684 -21.9...
#
# [1 rows x 65 columns]

# %%
gdf[gdf["sov_a3"]=="PER"]
# Out:
#    scalerank       featurecla  labelrank sovereignt sov_a3  adm0_dif  level  \
# 7          1  Admin-0 country          2       Peru    PER         0      2
#
#                 type admin adm0_a3  ...  region_un      subregion  \
# 7  Sovereign country  Peru     PER  ...   Americas  South America
#
#                    region_wb  name_len long_len abbrev_len  tiny homepart  \
# 7  Latin America & Caribbean         4        4          4   -99        1
#
#       filename                                           geometry
# 7  PER.geojson  POLYGON ((-69.59042 -17.58001, -69.85844 -18.0...
#
# [1 rows x 65 columns]

# %%
gdf.plot()
plt.title("SA")
plt.show()

# %%
gdf.columns
# Out:
# Index(['scalerank', 'featurecla', 'labelrank', 'sovereignt', 'sov_a3',
#        'adm0_dif', 'level', 'type', 'admin', 'adm0_a3', 'geou_dif', 'geounit',
#        'gu_a3', 'su_dif', 'subunit', 'su_a3', 'brk_diff', 'name', 'name_long',
#        'brk_a3', 'brk_name', 'brk_group', 'abbrev', 'postal', 'formal_en',
#        'formal_fr', 'note_adm0', 'note_brk', 'name_sort', 'name_alt',
#        'mapcolor7', 'mapcolor8', 'mapcolor9', 'mapcolor13', 'pop_est',
#        'gdp_md_est', 'pop_year', 'lastcensus', 'gdp_year', 'economy',
#        'income_grp', 'wikipedia', 'fips_10', 'iso_a2', 'iso_a3', 'iso_n3',
#        'un_a3', 'wb_a2', 'wb_a3', 'woe_id', 'adm0_a3_is', 'adm0_a3_us',
#        'adm0_a3_un', 'adm0_a3_wb', 'continent', 'region_un', 'subregion',
#        'region_wb', 'name_len', 'long_len', 'abbrev_len', 'tiny', 'homepart',
#        'filename', 'geometry'],
#       dtype='object')

# %%
gdf[["sovereignt","sov_a3", "geometry"]]
# Out:
#         sovereignt sov_a3                                           geometry
# 0          Bolivia    BOL  POLYGON ((-62.84647 -22.03498, -63.98684 -21.9...
# 1           Brazil    BRA  POLYGON ((-57.62513 -30.2163, -56.2909 -28.852...
# 2        Argentina    ARG  MULTIPOLYGON (((-65.5 -55.2, -66.45 -55.25, -6...
# 3            Chile    CHL  MULTIPOLYGON (((-68.63401 -52.63637, -68.63335...
# 4         Colombia    COL  POLYGON ((-75.37322 -0.15203, -75.80147 0.0848...
# 5           Guyana    GUY  POLYGON ((-59.75828 8.36704, -59.10168 7.9992,...
# 6          Ecuador    ECU  POLYGON ((-80.30256 -3.40486, -79.77029 -2.657...
# 7             Peru    PER  POLYGON ((-69.59042 -17.58001, -69.85844 -18.0...
# 8   United Kingdom    GB1  POLYGON ((-61.2 -51.85, -60 -51.25, -59.15 -51...
# 9         Paraguay    PRY  POLYGON ((-62.68506 -22.24903, -62.29118 -21.0...
# 10        Suriname    SUR  POLYGON ((-57.14744 5.97315, -55.94932 5.77288...
# ...

# %%
gdf1 = gdf[["sovereignt","sov_a3", "geometry"]]

# %%
output_geojson_file = 'country_participants.geojson'
gdf1.to_file(output_geojson_file, driver='GeoJSON')
